# %% [markdown]
# # Teorema del Límite Central:

# %% [markdown]
# ## Distribución Normal

# %%
mu=100; sigma=10
n=100
xbar=rep(0,500)
for (i in 1:500) {xbar[i]=mean(rnorm(n,mean=mu,sd=sigma))}
#xbar;
max=sqrt(n)/(sigma*sqrt(2*pi))
max
hist(xbar,prob=TRUE,breaks=25,xlim=c(mu-3*sigma/sqrt(n),mu+3*sigma/sqrt(n)),col="yellow",ylim=c(0,1.5*max))
curve(dnorm(x, mean=mu, sd=sigma/sqrt(n)), 
      col="darkblue", lwd=2, add=TRUE, yaxt="n")
# Out:
# [1] 0.3989423
# Plot with title “Histogram of xbar”

# %%
mu=100; sigma=10
n=100
xbar=rep(0,500)
for (i in 1:500) {xbar[i]=mean(rnorm(n,mean=mu,sd=sigma))}
g =
m<-mean(g)
std<-sqrt(var(g)/n)
hist(g, density=20, breaks=20, prob=TRUE, 
     xlab="x-variable", ylim=c(0, 2), 
     main="normal curve over histogram")
curve(dnorm(x, mean=m, sd=std), 
      col="darkblue", lwd=2, add=TRUE, yaxt="n")
# Out:
# Error in mean(g): object 'g' not found
# Traceback:
#
# 1. mean(g)
